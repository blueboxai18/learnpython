# %%
print("Your name?")
# Out:
# Your name?

# %% [markdown]
# <H1>This is Python langauge<H1>
#
#   I wanted to put this notes for myself and others' reference

# %%
print("Kalyan")
# Out:
# Kalyan

# %%
student1 ="John Doe"
student2="Jane Doe, and"
rating ="are very good students"
print(student2, student1, rating)
# Out:
# Jane Doe, and John Doe are very good students
